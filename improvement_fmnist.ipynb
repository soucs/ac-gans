# %% [markdown]
# <a href="https://colab.research.google.com/github/soucs/ac-gans/blob/main/ac_gans_with_ssim_loss.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import torch
import torchvision
from torchvision.transforms import ToTensor, Normalize, Compose
from torchvision.datasets import MNIST, FashionMNIST
from torch.nn.functional import one_hot
from torch.utils.data import DataLoader
import torch.nn as nn

# mnist = MNIST(root='data', 
#               train=True, 
#               download=True,
#               transform=Compose([ToTensor(), Normalize(mean=(0.5,), std=(0.5,))]))
fmnist = FashionMNIST(root='data', 
              train=True, 
              download=True,
              transform=Compose([ToTensor(), Normalize(mean=(0.5,), std=(0.5,))]))

# %%
image_size = 784
n_classes = 10
batch_size = 100

data_loader = DataLoader(fmnist, batch_size, shuffle=True)

# %%
def denorm(x):
    out = (x + 1) / 2
    return out.clamp(0, 1)
# View image
def view(img):
    img = img.reshape(28,28)
    img_norm = denorm(img).detach()
    plt.imshow(img_norm, cmap='gray')
def get_z(classes):
    z = torch.randn(batch_size, latent_size)
    y = one_hot(classes.reshape(batch_size),num_classes = n_classes)
    z = torch.cat([z, y], dim=1)
    return z

# %%
hidden_size = 256
latent_size = 64

D = nn.Sequential(
    nn.Linear(image_size, hidden_size),
    nn.LeakyReLU(0.2),
    nn.Linear(hidden_size, hidden_size),
    nn.LeakyReLU(0.2))
D_out = nn.Sequential(
    nn.Linear(hidden_size, 1),
    nn.Sigmoid())
A_out = nn.Sequential(
    nn.Linear(hidden_size, 10),
    nn.Softmax())

G = nn.Sequential(
    nn.Linear(latent_size+n_classes, hidden_size),
    nn.ReLU(),
    nn.Linear(hidden_size, hidden_size),
    nn.ReLU(),
    nn.Linear(hidden_size, image_size),
    nn.Tanh())

# %%
criterion = nn.BCELoss()
aux_criterion = nn.CrossEntropyLoss()

# Train Discriminator
d_optimizer = torch.optim.Adam(D.parameters(), lr=0.0002)

def train_discriminator(images,classes):
    real_labels = torch.ones(batch_size,1)
    fake_labels = torch.zeros(batch_size,1)
        
    # Loss for real images
    outputs = D(images)
    rf_out = D_out(outputs)
    aux_out = A_out(outputs)
    d_loss_real = criterion(rf_out, real_labels)
    d_loss_rclass = aux_criterion(aux_out, classes)

    # Loss for fake images
    z = get_z(classes)
    fake_images = G(z)
    outputs = D(fake_images)
    rf_out = D_out(outputs)
    aux_out = A_out(outputs)
    d_loss_fake = criterion(rf_out, fake_labels)
    d_loss_fclass = aux_criterion(aux_out, classes)

    # Combine losses
    Ls = d_loss_real + d_loss_fake
    Lc = d_loss_rclass + d_loss_fclass
    d_loss = Lc + Ls

    reset_grad()
    d_loss.backward()
    d_optimizer.step()
    
    return d_loss

# Train Generator
g_optimizer = torch.optim.Adam(G.parameters(), lr=0.0002)

def train_generator(classes):
    # Generate fake images and calculate loss
    real_labels = torch.ones(batch_size,1)

    # Loss for fake images
    z = get_z(classes)
    fake_images = G(z)
    outputs = D(fake_images)
    rf_out = D_out(outputs)
    aux_out = A_out(outputs)
    g_loss_fake = criterion(rf_out, real_labels)
    g_loss_fclass = aux_criterion(aux_out, classes)

    sim_scores = []
    for i in range(10):
        class_imgs = fake_images[np.where(classes==i)]
        try:
          imgx = class_imgs[0]
          imgy = class_imgs[1]
          sim_scores.append(ssim(imgx,imgy))
        except IndexError:
          continue
    sim_loss = torch.mean(torch.tensor(sim_scores))


    # Combine losses
    g_loss = g_loss_fake + g_loss_fclass + sim_loss

    # Backprop and optimize
    reset_grad()
    g_loss.backward()
    g_optimizer.step()
    return g_loss

def reset_grad():
  d_optimizer.zero_grad()
  g_optimizer.zero_grad()

# %%
# for images,classes in data_loader:
#   images = images.reshape(batch_size, -1)
#   ld = train_discriminator(images,classes)
#   lg = train_generator(classes)
#   print(ld,lg)
#   break

# %%
import os
from IPython.display import Image
from torchvision.utils import save_image

sample_dir = 'samples'
if not os.path.exists(sample_dir):
    os.makedirs(sample_dir)

for i, classes in data_loader:
    sample_vectors = get_z(classes)
    break

def save_fake_images(index):
    fake_images = G(sample_vectors)
    # for i in range(10):
    #     idx = np.where(classes==i)
    #     img1 = fake_images[idx[0][0]].reshape(28,28)
    #     img2 = fake_images[idx[0][1]].reshape(28,28)
    #     save_image(denorm(img1),os.path.join(sample_dir, f'{i}_{index}_1.png'))
    #     save_image(denorm(img2),os.path.join(sample_dir, f'{i}_{index}_2.png'))
    fake_images = fake_images.reshape(fake_images.size(0), 1, 28, 28)
    fake_fname = 'fake_images-{0:0=4d}.png'.format(index)
    print('Saving', fake_fname)
    save_image(denorm(fake_images), os.path.join(sample_dir, fake_fname), nrow=10)

# Before training
save_fake_images(0)
Image(os.path.join(sample_dir, 'fake_images-0000.png'))
# Out:
# Saving fake_images-0000.png

# %%
def ssim(imgx,imgy):
  K1, K2, L = 0.01, 0.03, 255
  C1, C2 = (K1*L)**2, (K2*L)**2
  C3 = C2/2

  mu_x = torch.mean(imgx)
  mu_y = torch.mean(imgy)
  sd_x = torch.std(imgx)
  sd_y = torch.std(imgy)
  concat = torch.cat([imgx.flatten(),imgy.flatten()])
  cov_xy = torch.cov(concat) #[0,1]

  l = (2*mu_x*mu_y + C1)/(mu_x**2 + mu_y**2 + C1)
  c = (2*sd_x*sd_y + C2)/(sd_x**2 + sd_y**2 + C2)
  s = (cov_xy + C3)/(sd_x*sd_y + C3)

  return l*c*s

# %%
num_epochs = 100
total_step = len(data_loader)
d_losses, g_losses = [], []

for epoch in range(num_epochs):
    for i, (images, classes) in enumerate(data_loader):
        images = images.reshape(batch_size, -1)
        d_loss = train_discriminator(images,classes)
        g_loss = train_generator(classes)

    d_losses.append(d_loss.item())
    g_losses.append(g_loss.item())
    print('Epoch [{}/{}], Step [{}/{}], d_loss: {:.4f}, g_loss: {:.4f}' 
          .format(epoch+1, num_epochs, i+1, total_step, d_loss.item(), g_loss.item()))
    
    
    # Sample and save images
    save_fake_images(epoch+1)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/container.py:217: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# Epoch [1/100], Step [600/600], d_loss: 4.2020, g_loss: 6.2357
# Saving fake_images-0001.png
# Epoch [2/100], Step [600/600], d_loss: 4.1034, g_loss: 7.4074
# Saving fake_images-0002.png
# Epoch [3/100], Step [600/600], d_loss: 4.0427, g_loss: 8.5182
# Saving fake_images-0003.png
# Epoch [4/100], Step [600/600], d_loss: 4.0109, g_loss: 7.6487
# Saving fake_images-0004.png
# Epoch [5/100], Step [600/600], d_loss: 4.1053, g_loss: 7.7004
# Saving fake_images-0005.png
# Epoch [6/100], Step [600/600], d_loss: 4.0585, g_loss: 8.1140
# Saving fake_images-0006.png
# Epoch [7/100], Step [600/600], d_loss: 4.1625, g_loss: 7.9917
# Saving fake_images-0007.png
# Epoch [8/100], Step [600/600], d_loss: 4.1986, g_loss: 6.1960
# Saving fake_images-0008.png
# Epoch [9/100], Step [600/600], d_loss: 4.0006, g_loss: 7.8092
# Saving fake_images-0009.png
# Epoch [10/100], Step [600/600], d_loss: 4.0954, g_loss: 9.3936
# Saving fake_images-0010.png
# Epoch [11/100], Step [600/600], d_loss: 4.0281, g_loss: 8.6126
# Saving fake_images-0011.png
# Epoch [12/100], Step [600/600], d_loss: 4.0581, g_loss: 8.7089
# Saving fake_images-0012.png
# Epoch [13/100], Step [600/600], d_loss: 4.0972, g_loss: 7.6903
# Saving fake_images-0013.png
# Epoch [14/100], Step [600/600], d_loss: 4.1258, g_loss: 7.6358
# Saving fake_images-0014.png
# Epoch [15/100], Step [600/600], d_loss: 4.4085, g_loss: 6.7212
# Saving fake_images-0015.png
# Epoch [16/100], Step [600/600], d_loss: 4.1164, g_loss: 5.9149
# Saving fake_images-0016.png
# Epoch [17/100], Step [600/600], d_loss: 4.0984, g_loss: 6.3673
# Saving fake_images-0017.png
# Epoch [18/100], Step [600/600], d_loss: 4.0256, g_loss: 5.7299
# Saving fake_images-0018.png
# Epoch [19/100], Step [600/600], d_loss: 4.1996, g_loss: 7.2406
# Saving fake_images-0019.png
# Epoch [20/100], Step [600/600], d_loss: 4.0535, g_loss: 6.3421
# Saving fake_images-0020.png
# Epoch [21/100], Step [600/600], d_loss: 4.0298, g_loss: 6.4253
# Saving fake_images-0021.png
# Epoch [22/100], Step [600/600], d_loss: 3.9713, g_loss: 6.2524
# Saving fake_images-0022.png
# Epoch [23/100], Step [600/600], d_loss: 3.8929, g_loss: 6.5279
# Saving fake_images-0023.png
# Epoch [24/100], Step [600/600], d_loss: 3.8697, g_loss: 6.7067
# Saving fake_images-0024.png
# Epoch [25/100], Step [600/600], d_loss: 4.1659, g_loss: 6.3942
# Saving fake_images-0025.png
# Epoch [26/100], Step [600/600], d_loss: 3.9547, g_loss: 6.2122
# Saving fake_images-0026.png
# Epoch [27/100], Step [600/600], d_loss: 3.7944, g_loss: 5.4093
# Saving fake_images-0027.png
# Epoch [28/100], Step [600/600], d_loss: 3.7470, g_loss: 5.5701
# Saving fake_images-0028.png
# Epoch [29/100], Step [600/600], d_loss: 4.0177, g_loss: 6.7950
# Saving fake_images-0029.png
# Epoch [30/100], Step [600/600], d_loss: 3.9226, g_loss: 5.7121
# Saving fake_images-0030.png
# Epoch [31/100], Step [600/600], d_loss: 3.8154, g_loss: 5.9642
# Saving fake_images-0031.png
# Epoch [32/100], Step [600/600], d_loss: 3.8658, g_loss: 5.5510
# Saving fake_images-0032.png
# Epoch [33/100], Step [600/600], d_loss: 4.0057, g_loss: 5.6087
# Saving fake_images-0033.png
# Epoch [34/100], Step [600/600], d_loss: 3.8162, g_loss: 4.8917
# Saving fake_images-0034.png
# Epoch [35/100], Step [600/600], d_loss: 4.0151, g_loss: 4.3768
# Saving fake_images-0035.png
# Epoch [36/100], Step [600/600], d_loss: 4.1125, g_loss: 5.0663
# Saving fake_images-0036.png
# Epoch [37/100], Step [600/600], d_loss: 3.9883, g_loss: 4.6654
# Saving fake_images-0037.png
# Epoch [38/100], Step [600/600], d_loss: 3.9413, g_loss: 4.5989
# Saving fake_images-0038.png
# Epoch [39/100], Step [600/600], d_loss: 3.7178, g_loss: 4.4779
# Saving fake_images-0039.png
# Epoch [40/100], Step [600/600], d_loss: 3.8773, g_loss: 4.6401
# Saving fake_images-0040.png
# Epoch [41/100], Step [600/600], d_loss: 3.8180, g_loss: 5.6160
# Saving fake_images-0041.png

# %%
import cv2
from IPython.display import FileLink

vid_fname = 'gans_training.avi'

files = [os.path.join(sample_dir, f) for f in os.listdir(sample_dir) if 'fake_images' in f]
files.sort()

out = cv2.VideoWriter(vid_fname,cv2.VideoWriter_fourcc(*'MP4V'), 8, (302,302))
[out.write(cv2.imread(fname)) for fname in files]
out.release()
FileLink('gans_training.avi')

# %%
# fake_images = G(sample_vectors)
# for i in range(10):
#     idx = np.where(classes==i)
#     img1 = fake_images[idx[0][0]].reshape(28,28)
#     img2 = fake_images[idx[0][1]].reshape(28,28)
#     save_image(denorm(img1),os.path.join(sample_dir, f'{i}_1.png'))
#     save_image(denorm(img2),os.path.join(sample_dir, f'{i}_2.png'))

# %%
# from torch.nn.functional import one_hot
# import torch
# for img,lab in data_loader:
#   break

# %%
# img[np.where(lab==0)[0]][0].shape

# %%
# import shutil
# archived = shutil.make_archive('fake_images', 'zip', 'samples')

# %% [markdown]
# # Testing

# %%
fmnist_test = FashionMNIST(root='data', 
              train=False, 
              download=True,
              transform=Compose([ToTensor(), Normalize(mean=(0.5,), std=(0.5,))]))
test_dl = DataLoader(fmnist_test, batch_size, shuffle=True)

# %%
for i, (images, classes) in enumerate(test_dl):
    images = images.reshape(batch_size, -1)
    z = get_z(classes)
    fake_images = G(z)
    sim_scores = []
    for i in range(10):
        class_imgs = fake_images[np.where(classes==i)]
        try:
          imgx = class_imgs[0]
          imgy = class_imgs[1]
          sim_scores.append(ssim(imgx,imgy))
        except IndexError:
          continue
    sim_loss = torch.mean(torch.tensor(sim_scores))
    print(sim_loss)
